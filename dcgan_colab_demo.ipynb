# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamswarnkar/Image-Generator/blob/master/dcgan_colab_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download Git Repo

# %%
# !git clone https://github.com/shivamswarnkar/Image-Generator.git gan
# %cd gan
# Out:
# Cloning into 'gan'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 77 (delta 0), reused 1 (delta 0), pack-reused 74
# Unpacking objects: 100% (77/77), done.
# /content/gan

# %% [markdown]
# # Download Dataset
# ### I'll show an example by downloading the kaggle dataset of landmark images

# %%
# Download dataset
# !wget 'https://storage.googleapis.com/kaggle-data-sets/23421/29962/bundle/archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1573501226&Signature=rpVKKYfPn9mTz6sOgMA0UtmnRv1m7peGxNNEjGaRJglT9Gz2cbh%2BDUaUuR5XDO6hY1QdtbZ9cX1Jq61FNJ3VuSuOYREQZVZvtEPWyFL6f9%2Fv7jDWh2MjhoaISZTAqg7ppyt%2B1LTERcSlPpSkug3hXCeKbytSaMSPCrZuqS8EBS9oLZyLgwlv5UQI5Rlgf5GOKtWxEQhOR7QC7C9dED0idCj8xOvrVYqmj8HltsFUyKcydX8J54c6XVFdvE5S2VNA27QWkFqaWmo7EYil%2BQ6QfhttdOV%2Fxy%2BJflFdqsb8hBjgNOd5cjtKKrH4in0Mo1gRoO4dIDRdiDAcDGA0cG90Ng%3D%3D&response-content-disposition=attachment%3B+filename%3Dlandmark-recognition.zip'
# Out:
# The name is too long, 526 chars total.
# Trying to shorten...
# New name is archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1573501226&Signature=rpVKKYfPn9mTz6sOgMA0UtmnRv1m7peGxNNEjGaRJglT9Gz2cbh+DUaUuR5XDO6hY1QdtbZ9cX1Jq61FNJ3VuSuOYREQZVZvtEPWyFL6f9%2Fv7jDWh2MjhoaISZTAqg7ppyt.
# --2019-11-08 19:45:51--  https://storage.googleapis.com/kaggle-data-sets/23421/29962/bundle/archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1573501226&Signature=rpVKKYfPn9mTz6sOgMA0UtmnRv1m7peGxNNEjGaRJglT9Gz2cbh%2BDUaUuR5XDO6hY1QdtbZ9cX1Jq61FNJ3VuSuOYREQZVZvtEPWyFL6f9%2Fv7jDWh2MjhoaISZTAqg7ppyt%2B1LTERcSlPpSkug3hXCeKbytSaMSPCrZuqS8EBS9oLZyLgwlv5UQI5Rlgf5GOKtWxEQhOR7QC7C9dED0idCj8xOvrVYqmj8HltsFUyKcydX8J54c6XVFdvE5S2VNA27QWkFqaWmo7EYil%2BQ6QfhttdOV%2Fxy%2BJflFdqsb8hBjgNOd5cjtKKrH4in0Mo1gRoO4dIDRdiDAcDGA0cG90Ng%3D%3D&response-content-disposition=attachment%3B+filename%3Dlandmark-recognition.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.206.128, 2a00:1450:400c:c0c::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.206.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 941925743 (898M) [application/zip]
# Saving to: ‘archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1573501226&Signature=rpVKKYfPn9mTz6sOgMA0UtmnRv1m7peGxNNEjGaRJglT9Gz2cbh+DUaUuR5XDO6hY1QdtbZ9cX1Jq61FNJ3VuSuOYREQZVZvtEPWyFL6f9%2Fv7jDWh2MjhoaISZTAqg7ppyt’
#
# archive.zip?GoogleA 100%[===================>] 898.29M  46.1MB/s    in 18s
#
# 2019-11-08 19:46:10 (49.8 MB/s) - ‘archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1573501226&Signature=rpVKKYfPn9mTz6sOgMA0UtmnRv1m7peGxNNEjGaRJglT9Gz2cbh+DUaUuR5XDO6hY1QdtbZ9cX1Jq61FNJ3VuSuOYREQZVZvtEPWyFL6f9%2Fv7jDWh2MjhoaISZTAqg7ppyt’ saved [941925743/941925743]

# %%
# rename downloaded zip file
! mv 'archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1573501226&Signature=rpVKKYfPn9mTz6sOgMA0UtmnRv1m7peGxNNEjGaRJglT9Gz2cbh+DUaUuR5XDO6hY1QdtbZ9cX1Jq61FNJ3VuSuOYREQZVZvtEPWyFL6f9%2Fv7jDWh2MjhoaISZTAqg7ppyt' 'landmark.zip'

# %%
# !ls
# Out:
# checkpoints  demo_imgs	    generator	  output	     train.py
# data	     discriminator  landmark.zip  pretrained_models  utils
# DCGAN	     generate.py    LICENSE	  README.md

# %%
# setup dataroot
# !mkdir data/landmark

# %%
# unzip zip file
# !unzip -qq landmark.zip -d data/landmark

# %%
# !ls data/landmark
# Out:
# images	Images	labels.csv  train.csv

# %%
# delete unecessary data
# !rm -r data/landmark/Images
# !rm data/landmark/labels.csv
# !rm data/landmark/train.csv

# %%
# setup dir such data images are at data/landmark/Images
# !mv data/landmark/images/Images data/landmark/Images

# %%
# !rm -r data/landmark/images

# %% [markdown]
# # Training from Scratch Using Image Generator

# %%
# !python train.py --dataroot data/landmark/ --num_epochs 5
# Out:
# Starting Training Loop....
# [1/5][1/172]  						Loss_D:2.1786  						Loss_G:2.9364  						D(x):0.2811  						D(G(z)):0.4167/0.0762
# Made a New Checkpoint for 1
# [2/5][1/172]  						Loss_D:1.2398  						Loss_G:5.2131  						D(x):0.4378  						D(G(z)):0.0216/0.0178
# [3/5][1/172]  						Loss_D:0.3953  						Loss_G:3.1924  						D(x):0.7902  						D(G(z)):0.1083/0.0526
# [4/5][1/172]  						Loss_D:1.2105  						Loss_G:6.0249  						D(x):0.8710  						D(G(z)):0.5656/0.0053
# [5/5][1/172]  						Loss_D:2.1796  						Loss_G:2.6940  						D(x):0.2551  						D(G(z)):0.0161/0.1598

# %% [markdown]
# # Generate Images from Trained Generator

# %%
# generate sample images; by default checkpoints are made as checkpoints/netG.pth
# !python generate.py --netG checkpoints/netG.pth

# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
output = Image.open('output/fake.png')
plt.imshow(output)
plt.axis("off")
plt.show()

# %% [markdown]
# # Resuming Training

# %%
# !python train.py --dataroot data/landmark/ --netG checkpoints/netG.pth --netD checkpoints/netD.pth --num_epochs 50
# Out:
# Starting Training Loop....
# [1/50][1/172]  						Loss_D:1.6958  						Loss_G:1.0552  						D(x):0.3280  						D(G(z)):0.0133/0.4190
# Made a New Checkpoint for 1
# [2/50][1/172]  						Loss_D:1.3068  						Loss_G:5.6475  						D(x):0.8815  						D(G(z)):0.6138/0.0122
# [3/50][1/172]  						Loss_D:1.0679  						Loss_G:3.6397  						D(x):0.6909  						D(G(z)):0.3882/0.0438
# [4/50][1/172]  						Loss_D:0.6478  						Loss_G:3.7633  						D(x):0.8009  						D(G(z)):0.2861/0.0453
# [5/50][1/172]  						Loss_D:1.9187  						Loss_G:0.7784  						D(x):0.3268  						D(G(z)):0.1030/0.6067
# [6/50][1/172]  						Loss_D:2.6840  						Loss_G:8.9228  						D(x):0.9346  						D(G(z)):0.8293/0.0027
# Made a New Checkpoint for 6
# [7/50][1/172]  						Loss_D:0.4688  						Loss_G:3.2597  						D(x):0.7554  						D(G(z)):0.0834/0.0966
# [8/50][1/172]  						Loss_D:0.6086  						Loss_G:3.0891  						D(x):0.7561  						D(G(z)):0.2124/0.0680
# [9/50][1/172]  						Loss_D:3.0621  						Loss_G:6.9352  						D(x):0.9840  						D(G(z)):0.8938/0.0082
# [10/50][1/172]  						Loss_D:3.6204  						Loss_G:7.2754  						D(x):0.9933  						D(G(z)):0.8952/0.0468
# [11/50][1/172]  						Loss_D:1.0015  						Loss_G:4.9020  						D(x):0.9063  						D(G(z)):0.5193/0.0130
# Made a New Checkpoint for 11
# [12/50][1/172]  						Loss_D:0.6180  						Loss_G:4.3426  						D(x):0.8444  						D(G(z)):0.3054/0.0289
# [13/50][1/172]  						Loss_D:2.0913  						Loss_G:6.3214  						D(x):0.9373  						D(G(z)):0.7763/0.0091
# [14/50][1/172]  						Loss_D:1.4979  						Loss_G:0.6454  						D(x):0.3496  						D(G(z)):0.0561/0.6154
# [15/50][1/172]  						Loss_D:1.3207  						Loss_G:6.5558  						D(x):0.9691  						D(G(z)):0.6364/0.0033
# [16/50][1/172]  						Loss_D:3.6854  						Loss_G:7.4254  						D(x):0.9937  						D(G(z)):0.9427/0.0032
# Made a New Checkpoint for 16
# [17/50][1/172]  						Loss_D:3.0583  						Loss_G:7.2880  						D(x):0.9749  						D(G(z)):0.8781/0.0102
# [18/50][1/172]  						Loss_D:0.5837  						Loss_G:2.8393  						D(x):0.7118  						D(G(z)):0.1377/0.1100
# [19/50][1/172]  						Loss_D:2.0634  						Loss_G:7.6904  						D(x):0.9894  						D(G(z)):0.8083/0.0012
# [20/50][1/172]  						Loss_D:2.7181  						Loss_G:5.8777  						D(x):0.9835  						D(G(z)):0.8616/0.0180
# [21/50][1/172]  						Loss_D:3.6571  						Loss_G:6.5581  						D(x):0.9956  						D(G(z)):0.9205/0.0123
# Made a New Checkpoint for 21
# [22/50][1/172]  						Loss_D:2.4806  						Loss_G:5.1983  						D(x):0.9946  						D(G(z)):0.8267/0.0246
# [23/50][1/172]  						Loss_D:2.7624  						Loss_G:1.0728  						D(x):0.1213  						D(G(z)):0.0078/0.4443
# [24/50][1/172]  						Loss_D:1.2108  						Loss_G:4.3149  						D(x):0.8495  						D(G(z)):0.5358/0.0284
# [25/50][1/172]  						Loss_D:0.9044  						Loss_G:4.9263  						D(x):0.9088  						D(G(z)):0.4686/0.0155
# [26/50][1/172]  						Loss_D:0.5815  						Loss_G:4.3489  						D(x):0.9368  						D(G(z)):0.3697/0.0186
# Made a New Checkpoint for 26
# [27/50][1/172]  						Loss_D:1.2700  						Loss_G:5.2143  						D(x):0.9684  						D(G(z)):0.6262/0.0094
# [28/50][1/172]  						Loss_D:0.4168  						Loss_G:1.5982  						D(x):0.7210  						D(G(z)):0.0607/0.2480
# [29/50][1/172]  						Loss_D:0.7273  						Loss_G:6.0108  						D(x):0.9069  						D(G(z)):0.4025/0.0057
# [30/50][1/172]  						Loss_D:1.4407  						Loss_G:4.8747  						D(x):0.9243  						D(G(z)):0.6148/0.0183
# [31/50][1/172]  						Loss_D:1.1680  						Loss_G:6.4135  						D(x):0.9725  						D(G(z)):0.6041/0.0066
# Made a New Checkpoint for 31
# [32/50][1/172]  						Loss_D:0.4915  						Loss_G:1.2730  						D(x):0.6808  						D(G(z)):0.0503/0.3365
# [33/50][1/172]  						Loss_D:1.0279  						Loss_G:4.2941  						D(x):0.9162  						D(G(z)):0.4906/0.0295
# [34/50][1/172]  						Loss_D:0.7198  						Loss_G:6.8554  						D(x):0.9154  						D(G(z)):0.3902/0.0029
# [35/50][1/172]  						Loss_D:0.5375  						Loss_G:4.5392  						D(x):0.9374  						D(G(z)):0.3345/0.0174
# [36/50][1/172]  						Loss_D:1.0269  						Loss_G:5.8620  						D(x):0.9561  						D(G(z)):0.5348/0.0068
# Made a New Checkpoint for 36
# [37/50][1/172]  						Loss_D:1.0334  						Loss_G:6.3117  						D(x):0.9840  						D(G(z)):0.5649/0.0038
# [38/50][1/172]  						Loss_D:0.9891  						Loss_G:6.0779  						D(x):0.9534  						D(G(z)):0.4952/0.0060
# [39/50][1/172]  						Loss_D:0.4781  						Loss_G:5.5165  						D(x):0.9409  						D(G(z)):0.3049/0.0062
# [40/50][1/172]  						Loss_D:2.0824  						Loss_G:6.5934  						D(x):0.9965  						D(G(z)):0.8040/0.0042
# [41/50][1/172]  						Loss_D:2.4809  						Loss_G:1.7021  						D(x):0.7672  						D(G(z)):0.7390/0.3295
# Made a New Checkpoint for 41
# [42/50][1/172]  						Loss_D:0.5407  						Loss_G:4.5092  						D(x):0.8935  						D(G(z)):0.2915/0.0187
# [43/50][1/172]  						Loss_D:1.1681  						Loss_G:7.0284  						D(x):0.9939  						D(G(z)):0.6233/0.0015
# [44/50][1/172]  						Loss_D:0.2541  						Loss_G:3.2123  						D(x):0.8922  						D(G(z)):0.1181/0.0597
# [45/50][1/172]  						Loss_D:0.3783  						Loss_G:3.2880  						D(x):0.8393  						D(G(z)):0.1450/0.0700
# [46/50][1/172]  						Loss_D:0.5705  						Loss_G:3.9997  						D(x):0.9132  						D(G(z)):0.2908/0.0377
# Made a New Checkpoint for 46
# [47/50][1/172]  						Loss_D:4.5687  						Loss_G:5.8990  						D(x):0.9949  						D(G(z)):0.9684/0.0085
# [48/50][1/172]  						Loss_D:1.7269  						Loss_G:5.8414  						D(x):0.9752  						D(G(z)):0.6545/0.0166
# [49/50][1/172]  						Loss_D:0.6805  						Loss_G:5.9250  						D(x):0.9850  						D(G(z)):0.4192/0.0051
# [50/50][1/172]  						Loss_D:7.1515  						Loss_G:5.1856  						D(x):0.9999  						D(G(z)):0.9967/0.0219

# %% [markdown]
# # Generate Images from newly trained model

# %%
# !python generate.py --netG checkpoints/netG.pth

# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
output = Image.open('output/fake.png')
plt.imshow(output)
plt.axis("off")
plt.show()

# %% [markdown]
# # Save model to Google Drive

# %%
# By default, mdoels are saved in checkpoints dir. Once you close cloab, it'll remove all the data. 
# so for safety, you should move/download your importan files
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp checkpoints/netG.pth '/content/drive/My Drive/landmark_netG.pth'
# !cp checkpoints/netD.pth '/content/drive/My Drive/landmark_netD.pth'
